# %%
import plotly

# %%
import plotly.graph_objs as go

# %%
import cufflinks

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = 30

# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity = 'all'

# %%
from plotly.offline import iplot

# %%
cufflinks.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cufflinks.set_config_file(world_readable=True,theme='pearl')

# %%
df = pd.read_parquet('data/medium_data_2019_01_06')

# %%
dfb = bytes(df2,encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-911b32b8ab44> in <module>
# ----> 1 dfb = bytes(df2,encoding='utf8')
#
# NameError: name 'df2' is not defined

# %%
df['claps'].iplot(
kind='hist',
bins=30,
xTitle='claps',
linecolor='black',
yTitle='count',
title='Claps Distribution')
# Out:
# <div>
#
#
#             <div id="94cd6145-a617-4d82-b117-3d9d0a2f29dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("94cd6145-a617-4d82-b117-3d9d0a2f29dd")) {
#                     Plotly.newPlot(
#                         '94cd6145-a617-4d82-b117-3d9d0a2f29dd',
# ...

# %%
def to_time(dt):
    return dt.hour+dt.minute/60

# %%
df['time_started']=df['started_date'].apply(to_time)

# %%
df['time_published'] = df['published_date'].apply(to_time)
df[['time_started','time_published']].iplot(
kind='hist',
linecolor='black',
bins=24,
histnorm='percent',
bargap=0.1,
opacity=0.8,
barmode='overlay',
xTitle='time of day',
yTitle='(%)of articles',
title='aaaa')
# Out:
# <div>
#
#
#             <div id="a3ce6730-d3b4-44ba-a573-890faa6fd411" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a3ce6730-d3b4-44ba-a573-890faa6fd411")) {
#                     Plotly.newPlot(
#                         'a3ce6730-d3b4-44ba-a573-890faa6fd411',
# ...

# %%
df[['time_published', 'time_started']].iplot(
    kind='hist',
    bins=24,
    linecolor='black',
    opacity=0.8,
    histnorm='percent',
    barmode='overlay',
    xTitle='Time of day',
    yTitle='(%) of articles',
    title='Time Started and Time Published Overlaid')
# Out:
# <div>
#
#
#             <div id="542a696f-7c5e-4319-a1a5-d88756ffef92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("542a696f-7c5e-4319-a1a5-d88756ffef92")) {
#                     Plotly.newPlot(
#                         '542a696f-7c5e-4319-a1a5-d88756ffef92',
# ...

# %%
df_pub_fans_count=df.groupby('publication').count()['fans']

# %%
df_pub_fans_count
# Out:
# publication
# Engineering @ Feature Labs        1
# None                             41
# Noteworthy - The Journal Blog     1
# The Reality Project               3
# Towards Data Science             80
# Name: fans, dtype: int64

# %%
df_pub_fans_count.iplot(kind='bar',yTitle='number of articles',linecolor='black',title='articles by published')
# Out:
# <div>
#
#
#             <div id="7829965e-9348-4a16-b785-b0b31f2f93b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7829965e-9348-4a16-b785-b0b31f2f93b6")) {
#                     Plotly.newPlot(
#                         '7829965e-9348-4a16-b785-b0b31f2f93b6',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "fans", "orientation": "v", "text": "", "type": "bar", "x": ["Engineering @ Feature Labs", "None", "Noteworthy - The Journal Blog", "The Reality Project", "Towards Data Science"], "y": [1, 41, 1, 3, 80]}],
# ...

# %%
df[[c for c in df if '<tag>' in c]].sum().iplot(
    kind='bar',
    xTitle='Tag',
    yTitle='Number of Articles with Tag',
    title='Frequency of Tags',
    linecolor='black',
    sortbars=True)
# Out:
# <div>
#
#
#             <div id="2f8f0ed2-79b6-4e2b-8fef-2c65bed8faa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2f8f0ed2-79b6-4e2b-8fef-2c65bed8faa2")) {
#                     Plotly.newPlot(
#                         '2f8f0ed2-79b6-4e2b-8fef-2c65bed8faa2',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["<tag>Education", "<tag>Data Science", "<tag>Towards Data Science", "<tag>Machine Learning", "<tag>Python"], "y": [90, 77, 54, 51, 41]}],
# ...

# %%
df[[c for c in df if '<tag>' in c]].sum()
# Out:
# <tag>Education               90
# <tag>Data Science            77
# <tag>Towards Data Science    54
# <tag>Machine Learning        51
# <tag>Python                  41
# dtype: int64

# %%
df.iloc[0,3]
# Out:
# 'https://medium.com/p/screw-the-environment-but-consider-your-wallet-a4f7cd3d3161'

# %%
df2=df[['views','reads','published_date']].set_index('published_date').resample('M').mean()

# %%
df2.iplot(
    kind='bar',
    xTitle='Date',
    yTitle='Average',
    title='Monthly Average Views and Reads')
# Out:
# <div>
#
#
#             <div id="1d150740-f032-4e80-ada3-9f1bc7c1c5e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1d150740-f032-4e80-ada3-9f1bc7c1c5e4")) {
#                     Plotly.newPlot(
#                         '1d150740-f032-4e80-ada3-9f1bc7c1c5e4',
# ...

# %%
df2 = df[['views', 'read_time',
          'published_date']].set_index('published_date').resample('M').mean()

# %%
df2.iplot(kind='bar',xTitle='Date',secondary_y='read_time',secondary_y_title='Average Read Time',
         yTitle='Average Views',title='monthly averages')
# Out:
# <div>
#
#
#             <div id="7fe48e00-173f-4fea-a55d-0c1fe8902638" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7fe48e00-173f-4fea-a55d-0c1fe8902638")) {
#                     Plotly.newPlot(
#                         '7fe48e00-173f-4fea-a55d-0c1fe8902638',
# ...

# %%
df[['claps','fans']].iplot(secondary_y='fans',secondary_y_title='Fans',kind='box',yTitle='Claps',title='Box plot')
# Out:
# <div>
#
#
#             <div id="607bf8f0-e0bd-4a5f-94ee-debe856c17cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("607bf8f0-e0bd-4a5f-94ee-debe856c17cd")) {
#                     Plotly.newPlot(
#                         '607bf8f0-e0bd-4a5f-94ee-debe856c17cd',
# ...

# %%
df2 = df.pivot(
    columns='publication', values='fans')

# %%
df2
# Out:
# publication  Engineering @ Feature Labs  None  Noteworthy - The Journal Blog  \
# 0                                   NaN   NaN                            NaN
# 1                                   NaN   NaN                            NaN
# 2                                   NaN   NaN                            NaN
# 3                                   NaN  34.0                            NaN
# 4                                   NaN  47.0                            NaN
# ..                                  ...   ...                            ...
# 121                                 NaN  19.0                            NaN
# 122                                 NaN   0.0                            NaN
# 123                                 NaN   NaN                            NaN
# 124                                 NaN   NaN                            NaN
# 125                                 NaN   5.0                            NaN
#
# ...

# %%
df2=df.pivot(columns='publication',values='fans')

# %%
df2.head()
# Out:
# publication  Engineering @ Feature Labs  None  Noteworthy - The Journal Blog  \
# 0                                   NaN   NaN                            NaN
# 1                                   NaN   NaN                            NaN
# 2                                   NaN   NaN                            NaN
# 3                                   NaN  34.0                            NaN
# 4                                   NaN  47.0                            NaN
#
# publication  The Reality Project  Towards Data Science
# 0                           34.0                   NaN
# 1                           29.0                   NaN
# 2                           13.0                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN

# %%
df2.iplot(
kind='box',
layout=dict(
height=600,
yaxis=dict(title='fans'),title='fans by publication',margin=dict(t=140)))
# Out:
# <div>
#
#
#             <div id="631eed40-3e42-4259-ac0f-2f6d1b6e1368" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("631eed40-3e42-4259-ac0f-2f6d1b6e1368")) {
#                     Plotly.newPlot(
#                         '631eed40-3e42-4259-ac0f-2f6d1b6e1368',
# ...

# %%
df2.iplot(kind='box',yTitle='fans',title='fans by publication',margin=dict(t=200))
# Out:
# <div>
#
#
#             <div id="8def4d2f-35d3-4198-a803-45cac78b9040" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8def4d2f-35d3-4198-a803-45cac78b9040")) {
#                     Plotly.newPlot(
#                         '8def4d2f-35d3-4198-a803-45cac78b9040',
# ...

# %%
data[0].iplot(
kind='hist',
bins=50,
xTitle='claps',
linecolor='black',
yTitle='count',
title='Claps Distribution',
yaxis=)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-70-c2f8182f08b0> in <module>
#       6 yTitle='count',
#       7 title='Claps Distribution',
# ----> 8 yaxis=[0,100,200,400])
#
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     694         for key in list(kwargs.keys()):
# ...

# %%
li=[7, 11, 19, 25, 16, 20, 17, 52, 31, 31, 31, 31, 61, 31, 48, 37, 78, 85, 13, 85, 73, 21, 85, 97, 29, 85, 73, 109, 42, 61, 61, 61, 85, 73, 41, 61, 21, 21, 37, 868, 206, 75, 25, 37, 50, 36, 193, 89, 20, 37, 41, 37, 97, 36, 1046, 37, 37, 97, 25, 25, 713, 61, 29, 17, 37, 100, 61, 73, 61, 85, 677, 5, 13, 61, 97, 10, 29, 17, 85, 1223, 215, 81, 21, 16, 1386, 537, 1081, 39, 500, 1091, 37, 31, 49, 73, 73, 73, 37, 64, 31, 14, 48, 37, 78, 85, 33, 13, 85, 98, 98, 73, 49, 17, 48, 115, 49, 49, 98, 73, 85, 97, 21, 78, 49, 85, 73, 98, 109, 61, 85, 73, 41, 41, 49, 49, 73, 21, 21, 61, 61, 61, 61, 20, 61, 61, 37, 97, 37, 97, 29, 29, 21, 37, 85, 85, 85, 16, 45, 85, 21, 29, 42, 73, 41, 85, 61, 21, 20, 61, 61, 61, 21, 61, 61, 20, 61, 32, 61, 61, 37, 97, 37, 21, 32, 97, 25, 18, 18, 29, 29, 21, 21, 36, 20, 97, 97, 29, 29, 31, 31, 25, 37, 37, 85, 85, 21, 37, 37, 25, 21, 60, 60, 37, 36, 37, 36, 36, 85, 868, 206, 100, 50, 37, 215, 1046, 3699, 75, 33, 193, 89, 35, 37, 25, 29, 29, 29, 39, 13, 9, 9, 9, 13, 33, 49, 49, 73, 85, 49, 85, 25, 61, 61, 61, 61, 61, 51, 85, 373, 713, 1999, 61, 61, 37, 253, 73, 61, 97, 37, 335, 215, 54, 81, 191, 33, 37, 1999, 29, 17, 85, 10, 29, 17, 85, 37, 49, 49, 49, 49, 37, 37, 37, 73, 73, 73, 49, 49, 49, 37, 37, 37, 37, 49, 49, 37, 37, 23, 97, 97, 97, 97, 64, 202, 1449, 100, 677, 5, 97, 1280, 202, 243, 1386, 537, 1071, 1386, 500, 1091, 61, 61, 61, 61, 61, 61, 61, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 17, 17, 17, 17, 17, 33, 33, 33, 33, 33, 33, 33, 17, 17, 33, 33, 33, 33, 33, 33, 33, 33, 25, 56, 56, 56, 56, 56, 56, 56, 50, 50, 50, 50, 50, 50, 78, 12, 12, 10, 61, 202, 202, 100, 68, 13, 13, 13, 13, 19, 61, 61, 61, 61, 61, 61, 61, 61, 61, 17, 17, 17, 17, 17, 97, 17, 17, 53, 61, 217, 217, 85, 85, 85, 41, 115, 49, 33, 33, 45, 45, 44, 44, 27, 27, 29, 44, 7, 34, 61, 53, 78, 78, 78, 67, 67, 67, 67, 78, 78, 78, 78, 78, 78, 78, 78, 56, 56, 56, 56, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 60, 60, 60, 60, 61, 61, 61, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 67, 67, 67, 78, 78, 78, 78, 78, 78, 78, 78, 56, 56, 56, 56, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 77, 77, 77, 77, 78, 78, 78, 78, 78, 41, 41, 41, 45, 45, 77, 78, 78, 56, 78, 78, 78, 78, 56, 56, 56, 78, 78, 78, 77, 77, 78, 78, 45, 45, 45, 51, 51, 51, 77, 78, 78, 56, 78, 78, 78, 78, 56, 56, 56, 78, 78, 78, 78, 77, 78, 78, 45, 45, 45, 77, 78, 78, 56, 78, 78, 78, 78, 56, 56, 56, 78, 78, 78, 78, 77, 78, 78]

# %%
plt.hist(li, bins=20, normed=0, facecolor="blue", edgecolor="black", alpha=0.7)
# Out:
# C:\Users\housen\anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
#
#
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([609.,  18.,   4.,   4.,   2.,   6.,   2.,   4.,   0.,   0.,   2.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([   5. ,  189.7,  374.4,  559.1,  743.8,  928.5, 1113.2, 1297.9,
#         1482.6, 1667.3, 1852. , 2036.7, 2221.4, 2406.1, 2590.8, 2775.5,
#         2960.2, 3144.9, 3329.6, 3514.3, 3699. ]),
#  <a list of 20 Patch objects>)

# %%
data=pd.DataFrame(li)

# %%
d_200=data[data[0]<200]

# %%
d_50
# Out:
#       0
# 0     7
# 1    11
# 2    19
# 3    25
# 4    16
# ..   ..
# 608  45
# 609  45
# 631  45
# 632  45
# 633  45
#
# [241 rows x 1 columns]

# %%
d_50[0].iplot(
kind='hist',
bins=50,
xTitle='claps',
linecolor='black',
yTitle='count',
title='Claps Distribution')
# Out:
# <div>
#
#
#             <div id="6b85e662-21ad-432e-afa0-48de47f0a569" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6b85e662-21ad-432e-afa0-48de47f0a569")) {
#                     Plotly.newPlot(
#                         '6b85e662-21ad-432e-afa0-48de47f0a569',
# ...

# %%
d_100[0].iplot(
kind='hist',
bins=50,
xTitle='claps',
linecolor='black',
yTitle='count',
title='Claps Distribution',layout=dict(
yaxis=[0,40,60,80,100]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-2ccaf40cff0a> in <module>
#       6 yTitle='count',
#       7 title='Claps Distribution',layout=dict(
# ----> 8 yaxis=[0,40,60,80,100]))
#
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...

# %%
fig=d_200[0].iplot(
kind='hist',
bins=50,
xTitle='claps',
linecolor='black',
yTitle='count',
title='Claps Distribution',)
# Out:
# <div>
#
#
#             <div id="f2c3ea54-62b7-4b7d-979e-d4e19e99fe00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f2c3ea54-62b7-4b7d-979e-d4e19e99fe00")) {
#                     Plotly.newPlot(
#                         'f2c3ea54-62b7-4b7d-979e-d4e19e99fe00',
# ...

# %%
d_50[0]
# Out:
# 0       7
# 1      11
# 2      19
# 3      25
# 4      16
#        ..
# 608    45
# 609    45
# 631    45
# 632    45
# 633    45
# Name: 0, Length: 241, dtype: int64

# %%
import plotly.express as px

# %%
d_200[0]
# Out:
# 0       7
# 1      11
# 2      19
# 3      25
# 4      16
#        ..
# 647    78
# 648    78
# 649    77
# 650    78
# 651    78
# Name: 0, Length: 612, dtype: int64

# %%
fig=go.Figure(
    data=[go.Bar(y=[2,1,3])],
    layout_title_text='aaa',
)

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="189ef4a8-72c9-451f-9845-918ec22df9bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("189ef4a8-72c9-451f-9845-918ec22df9bb")) {
#                     Plotly.newPlot(
#                         '189ef4a8-72c9-451f-9845-918ec22df9bb',
#                         [{"type": "bar", "y": [2, 1, 3]}],
# ...

# %%
fig=px.histogram()

# %%
import plotly.io as pio
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook_connected'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %%
import plotly.io as pio
pio.renderers.default = "browser"

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with the 'svg' Renderer"
)
fig.show()

# %%
import plotly.express as px

fig = px.histogram(li)

fig.show()
# Out:
# <div>
#
#
#             <div id="b1a23e0a-95fc-4d74-847a-764b54faed6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b1a23e0a-95fc-4d74-847a-764b54faed6b")) {
#                     Plotly.newPlot(
#                         'b1a23e0a-95fc-4d74-847a-764b54faed6b',
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(
    data=(go.Scatter(y=[1,4,5],mode='markers'),),
    layout=go.Layout(
        title=go.layout.Title(text="A Figure Specified By A Graph Object")
    )
)

fig.show()
# Out:
# <div>
#
#
#             <div id="8e00360c-5eea-49fa-abb7-bcaf83d21852" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e00360c-5eea-49fa-abb7-bcaf83d21852")) {
#                     Plotly.newPlot(
#                         '8e00360c-5eea-49fa-abb7-bcaf83d21852',
#                         [{"mode": "markers", "type": "scatter", "y": [1, 4, 5]}],
# ...

# %%
a=df['fans']

# %%
x=a.index

# %%
y=df['fans'].values

# %%
import plotly.express as px

# %%
test_dict = {'id':[1,2,3,4,5,6],
             'name':['Alice','Bob','Cindy','Eric','Helen','Grace '],
             'math':[90,89,99,78,97,93],'english':[89,94,80,94,94,90]}
df=pd.DataFrame(test_dict,index=(i for i inrang))

# %%
df=pd.DataFrame(test_dict,index=(i for i inrang))

# %%
fig =px.scatter(df,x='id',y='english')

# %%
import numpy as np
import plotly.figure_factory as ff

x1,y1 = np.meshgrid(np.arange(0, 2, .2), np.arange(0, 2, .2))
u1 = np.cos(x1)*y1+0.5
v1 = np.sin(x1)*y1

fig = ff.create_quiver(x1, y1, u1, v1)

# %%
from plotly.subplots import make_subplots

# %%
0
# Out:
# <div>
#
#
#             <div id="85e1928e-b7b1-446a-b9b0-da912b401f8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85e1928e-b7b1-446a-b9b0-da912b401f8d")) {
#                     Plotly.newPlot(
#                         '85e1928e-b7b1-446a-b9b0-da912b401f8d',
#                         [{"mode": "markers", "type": "scatter", "x": [89, 94, 80, 94, 94, 90], "xaxis": "x", "y": [1, 2, 3, 4, 5, 6], "yaxis": "y"}],
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Bar(x=df['id'],y=df['english']))
fig.add_trace(go.Scatter(x=[1,2,3],y=[4,5,6]))
# Out:
# <div>
#
#
#             <div id="f38fe508-d219-4ce8-bf08-84f4f8493af7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f38fe508-d219-4ce8-bf08-84f4f8493af7")) {
#                     Plotly.newPlot(
#                         'f38fe508-d219-4ce8-bf08-84f4f8493af7',
#                         [{"type": "bar", "x": [1, 2, 3, 4, 5, 6], "y": [89, 94, 80, 94, 94, 90]}],
# ...

# %%
import plotly.express as px

# %%
fig=px.scatter(df,x='id',y='english',color='math',title='aaa')
fig.add_trace(go.Scatter(x=[2,4],y=[20,60],mode='lines',line=go.scatter.Line(color='red'),showlegend=False))
# Out:
# <div>
#
#
#             <div id="f345ef68-a1e0-4002-9f4d-4f53809500f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f345ef68-a1e0-4002-9f4d-4f53809500f1")) {
#                     Plotly.newPlot(
#                         'f345ef68-a1e0-4002-9f4d-4f53809500f1',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-e4cfaea6eda3> in <module>
# ----> 1 fig.add_trace(go.Scatter(x=[2,4],y=[20,60],mode='lines'),line=go.scatter.Line(color='gray'),showlegend=False)
#
# TypeError: add_trace() got an unexpected keyword argument 'line'

# %%
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2)

fig.add_scatter(y=[4, 2, 3.5], mode="markers",
                marker=dict(size=20, color="red"),
                name="a", row=1, col=1)

fig.add_bar(y=[2, 1, 3],
            marker=dict(color="MediumPurple"),
            name="b", row=1, col=1)

fig.add_scatter(y=[2, 3.5, 4], mode="markers",
                marker=dict(size=20, color="MediumPurple"),
                name="c", row=1, col=2)

fig.add_bar(y=[1, 3, 2],
            marker=dict(color="LightSeaGreen"),
            name="d", row=1, col=2)

fig.update_trace(marker_color='black',selector=dict(marker_color='MediumPurple'))
# Out:
# <div>
#
#
#             <div id="385aef14-62dc-47b7-b585-3d09b49c1f0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("385aef14-62dc-47b7-b585-3d09b49c1f0c")) {
#                     Plotly.newPlot(
#                         '385aef14-62dc-47b7-b585-3d09b49c1f0c',
#                         [{"marker": {"color": "red", "size": 20}, "mode": "markers", "name": "a", "type": "scatter", "xaxis": "x", "y": [4, 2, 3.5], "yaxis": "y"}],
# ...

# %%
fig.update_trace()
# Out:
# <div>
#
#
#             <div id="aa74b184-c8d2-42cd-be56-933c6de05098" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa74b184-c8d2-42cd-be56-933c6de05098")) {
#                     Plotly.newPlot(
#                         'aa74b184-c8d2-42cd-be56-933c6de05098',
# ...

# %%
iris=px.data.iris()

fig = px.scatter(iris, x="sepal_width", y="sepal_length", color="species",
                 title="Conditionally Updating Traces In A Plotly Express Figure With for_each_trace()")

# %%
fig.for_each_trace(lambda trace:trace.update(marker_symbol='square') if trace.name == 3 else() )
# Out:
# <div>
#
#
#             <div id="bbff763d-ae44-458a-850f-738236386655" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bbff763d-ae44-458a-850f-738236386655")) {
#                     Plotly.newPlot(
#                         'bbff763d-ae44-458a-850f-738236386655',
# ...

# %%
fig
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
trace.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-90af6bdef0c8> in <module>
# ----> 1 trace.name
#
# NameError: name 'trace' is not defined

# %%
import plotly.graph_objects as go
fig = go.Figure()
scatter = fig.add_trace(go.Scatter(x=[2,4,5,],y=[2, 3, 1]))

# %%
type(scatter)
# Out:
# plotly.graph_objs._figure.Figure

# %%
type(fig)
# Out:
# plotly.graph_objs._figure.Figure

# %%
fig.data[-1].marker.size=20

# %%
fig
# Out:
# <div>
#
#
#             <div id="c1b5079d-6184-47fb-ac1c-2a39a674c14d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1b5079d-6184-47fb-ac1c-2a39a674c14d")) {
#                     Plotly.newPlot(
#                         'c1b5079d-6184-47fb-ac1c-2a39a674c14d',
#                         [{"marker": {"size": 20}, "type": "scatter", "x": [2, 4, 5], "y": [2, 3, 1]}],
# ...
